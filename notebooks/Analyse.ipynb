# %%
from magazine import Magazine

# %%
ck = Magazine()

# %%
a1 = ck.get_authors(1973, 1985, threshold=5)
# Out:
# Anzahl Personen im Datenset: 297

# %%
a1.gender_stats()
# Out:
# male      222
# female     14
# Name: gender, dtype: int64

# %%
a2 = ck.get_authors(1991, 2000, threshold=5)
# Out:
# Anzahl Personen im Datenset: 218

# %%
a2.gender_stats()
# Out:
# male      162
# female     18
# Name: gender, dtype: int64

# %%
a3 = ck.get_authors(1962, 1972, threshold=5)
# Out:
# Anzahl Personen im Datenset: 259

# %%
a3.gender_stats()
# Out:
# male      207
# female     13
# Name: gender, dtype: int64

# %%
a3 = ck.get_authors(1920, 1930, threshold=1)
# Out:
# Anzahl Personen im Datenset: 569

# %%
a3.available_data()

# %%
a3.gender_stats()
# Out:
# male      394
# female     20
# Name: gender, dtype: int64

# %%
a = ck.get_authors(1920, 2000, threshold=5)
# Out:
# Anzahl Personen im Datenset: 1676

# %%
a.birth_year_stats()
# Out:
# year_of_birth
# -427.0      1
#  1207.0     1
#  1225.0     1
#  1491.0     1
#  1828.0     1
#  1859.0     1
#  1860.0     3
#  1863.0     1
#  1864.0     1
#  1865.0     4
#  1867.0     3
#  1868.0     5
#  1869.0     4
#  1870.0     7
#  1871.0     4
#  1872.0     7
#  1873.0     8
#  1874.0     7
#  1875.0     8
#  1876.0     6
#  1877.0     5
#  1878.0    12
#  1879.0     9
#  1880.0     9
#  1881.0     8
#  1882.0    11
#  1883.0    13
#  1884.0    15
#  1885.0    17
#  1886.0    15
#            ..
#  1937.0    24
#  1938.0    14
#  1939.0    10
#  1940.0    19
#  1941.0    10
#  1942.0    14
#  1943.0    10
#  1944.0    22
#  1945.0    16
#  1946.0    20
#  1947.0    26
#  1948.0    16
#  1949.0     9
#  1950.0    10
#  1951.0     6
#  1952.0     3
#  1953.0    10
#  1954.0     6
#  1955.0     9
#  1956.0     5
#  1957.0     6
#  1958.0     8
#  1959.0     2
#  1960.0     5
#  1961.0     4
#  1962.0     3
#  1963.0     1
#  1967.0     1
#  1968.0     1
#  1972.0     1
# ...
