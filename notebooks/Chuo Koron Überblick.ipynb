# %%
from magazine import Magazine

# %%
ck = Magazine()

# %% [markdown]
# # Überblick Geschlechterverhältnis

# %%
df = ck.gender_overview()
# Out:
#   0%|          | 5/1041 [00:00<00:22, 46.56it/s]
# Anzahl Personen im Datenset: 8825
# 100%|██████████| 1041/1041 [00:23<00:00, 44.45it/s]
# /home/pmuehleder/miniconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# # Überblick durchschnittliches Autorenalter

# %%
ck.age_overview()
# Out:
#   0%|          | 4/1041 [00:00<00:29, 35.71it/s]
# Anzahl Personen im Datenset: 8825
# 100%|██████████| 1041/1041 [00:23<00:00, 45.03it/s]
# /home/pmuehleder/miniconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Aneil von Artikel mit Autor von Todai

# %%
ck.education_overview()
# Out:
#   0%|          | 5/1041 [00:00<00:22, 45.32it/s]
# Anzahl Personen im Datenset: 8825
# 100%|██████████| 1041/1041 [00:21<00:00, 48.81it/s]
